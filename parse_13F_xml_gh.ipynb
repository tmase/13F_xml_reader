# %% [markdown]
# Berkshire Hathaway 13F: https://www.sec.gov/Archives/edgar/data/1067983/000095012322012275/18337.xml

# %%
# import libraries
import pandas as pd
import xml.etree.ElementTree as et
import numpy as np

# %%
latest_file = 'latest.xml'
prior_file = 'prior.xml'

# %%
def get_data(file):
    tree = et.parse(file)
    root = tree.getroot()
    ns = {'info': 'http://www.sec.gov/edgar/document/thirteenf/informationtable'}
    full_list = []
    for stocks in root.findall('info:infoTable', ns):
        issuer = stocks.find('info:nameOfIssuer', ns).text
        sec_type = stocks.find('info:titleOfClass', ns).text
        cusip = stocks.find('info:cusip', ns).text
        val = int(stocks.find('info:value', ns).text)
        # run subquery on stocks with different namespace
        shares = stocks.find('info:shrsOrPrnAmt',ns)
        amt = int(shares[0].text)
        full_list.append([issuer,sec_type,cusip,amt,val])
    df = pd.DataFrame(full_list,columns=['issuer','security_type','cusip','amount','value'])
    # create pivot table
    table = pd.pivot_table(df,index=['issuer','security_type','cusip'],aggfunc={'amount': np.sum,'value': np.sum})
    return table

# %%
df1 = get_data(latest_file)
df2 = get_data(prior_file)
df3 = df1.merge(df2,on=['issuer','security_type','cusip'],how='outer',suffixes=('_latest', '_prior'))

# %%
df3
# Out:
#                                                         amount_latest  \
# issuer                       security_type   cusip
# ACTIVISION BLIZZARD INC      COM             00507V109   5.271708e+07
# ALLY FINL INC                COM             02005N100   2.980000e+07
# AMAZON COM INC               COM             023135106   1.066600e+07
# AMERICAN EXPRESS CO          COM             025816109   1.516107e+08
# AON PLC                      SHS CL A        G0403H108   4.396000e+06
# APPLE INC                    COM             037833100   8.951362e+08
# BANK AMER CORP               COM             060505104   1.010101e+09
# BANK OF NEW YORK MELLON CORP COM             064058100   2.506987e+07
# CELANESE CORP DEL            COM             150870103   9.710183e+06
# CHARTER COMMUNICATIONS INC N CL A            16119P108   3.828941e+06
# CHEVRON CORP NEW             COM             166764100   1.629758e+08
# CITIGROUP INC                COM NEW         172967424   5.515580e+07
# COCA COLA CO                 COM             191216100   4.000000e+08
# DAVITA INC                   COM             23918K108   3.609557e+07
# FLOOR & DECOR HLDGS INC      CL A            339750101   4.780000e+06
# GENERAL MTRS CO              COM             37045V100   5.000000e+07
# GLOBE LIFE INC               COM             37959E102   6.353727e+06
# HP INC                       COM             40434L105   1.044760e+08
# JEFFERIES FINL GROUP INC     COM             47233W109   4.335580e+05
# JOHNSON & JOHNSON            COM             478160104   3.271000e+05
# KRAFT HEINZ CO               COM             500754106   3.256348e+08
# KROGER CO                    COM             501044101   5.000000e+07
# LIBERTY LATIN AMERICA LTD    COM CL A        G9001E102   2.630792e+06
#                              COM CL C        G9001E128   1.284020e+06
# LIBERTY MEDIA CORP DEL       COM SER C FRMLA 531229854   7.722451e+06
# LIBERTY MEDIA CORP DELAWARE  COM A SIRIUSXM  531229409   2.020768e+07
#                              COM C SIRIUSXM  531229607   4.320829e+07
# LOUISIANA PAC CORP           COM             546347105   7.044909e+06
# MARKEL CORP                  COM             570535104   4.676110e+05
# MARSH & MCLENNAN COS INC     COM             571748102   4.049110e+05
# MASTERCARD INC               CL A            57636Q104   3.986648e+06
# MCKESSON CORP                COM             58155Q103   2.855514e+06
# MONDELEZ INTL INC            CL A            609207105   5.780000e+05
# MOODYS CORP                  COM             615369105   2.466978e+07
# NU HLDGS LTD                 ORD SHS CL A    G6683N103   1.071188e+08
# OCCIDENTAL PETE CORP         COM             674599105   1.943516e+08
# PARAMOUNT GLOBAL             CLASS B COM     92556H206   9.363719e+07
# PROCTER & GAMBLE CO          COM             742718109   3.154000e+05
# RH                           COM             74967X103   2.360000e+06
# SNOWFLAKE INC                CL A            833445109   6.125376e+06
# SPDR S&P 500 ETF TR          TR UNIT         78462F103   3.940000e+04
# STONECO LTD                  COM CL A        G85158106   1.069545e+07
# T-MOBILE US INC              COM             872590104   5.242000e+06
# TAIWAN SEMICONDUCTOR MFG LTD SPONSORED ADS   874039100   8.292724e+06
# UNITED PARCEL SERVICE INC    CL B            911312106   5.940000e+04
# US BANCORP DEL               COM NEW         902973304   6.670835e+06
# VANGUARD INDEX FDS           S&P 500 ETF SHS 922908363   4.300000e+04
# VERISIGN INC                 COM             92343E102   1.281561e+07
# VISA INC                     COM CL A        92826C839   8.297460e+06
# NU HLDGS LTD                 ORD SHS CL A    G6693N103            NaN
#
#                                                         value_latest  \
# issuer                       security_type   cusip
# ACTIVISION BLIZZARD INC      COM             00507V109  4.035492e+09
# ALLY FINL INC                COM             02005N100  7.286100e+08
# AMAZON COM INC               COM             023135106  8.959440e+08
# AMERICAN EXPRESS CO          COM             025816109  2.240048e+10
# AON PLC                      SHS CL A        G0403H108  1.319415e+09
# APPLE INC                    COM             037833100  1.163050e+11
# BANK AMER CORP               COM             060505104  3.345453e+10
# BANK OF NEW YORK MELLON CORP COM             064058100  1.141180e+09
# CELANESE CORP DEL            COM             150870103  9.927691e+08
# CHARTER COMMUNICATIONS INC N CL A            16119P108  1.298394e+09
# CHEVRON CORP NEW             COM             166764100  2.925252e+10
# CITIGROUP INC                COM NEW         172967424  2.494697e+09
# COCA COLA CO                 COM             191216100  2.544400e+10
# DAVITA INC                   COM             23918K108  2.695256e+09
# FLOOR & DECOR HLDGS INC      CL A            339750101  3.328314e+08
# GENERAL MTRS CO              COM             37045V100  1.682000e+09
# GLOBE LIFE INC               COM             37959E102  7.659418e+08
# HP INC                       COM             40434L105  2.807271e+09
# JEFFERIES FINL GROUP INC     COM             47233W109  1.486237e+07
# JOHNSON & JOHNSON            COM             478160104  5.778222e+07
# KRAFT HEINZ CO               COM             500754106  1.325659e+10
# KROGER CO                    COM             501044101  2.229000e+09
# LIBERTY LATIN AMERICA LTD    COM CL A        G9001E102  1.980986e+07
#                              COM CL C        G9001E128  9.758552e+06
# LIBERTY MEDIA CORP DEL       COM SER C FRMLA 531229854  4.616481e+08
# LIBERTY MEDIA CORP DELAWARE  COM A SIRIUSXM  531229409  7.943639e+08
#                              COM C SIRIUSXM  531229607  1.690740e+09
# LOUISIANA PAC CORP           COM             546347105  4.170586e+08
# MARKEL CORP                  COM             570535104  6.160728e+08
# MARSH & MCLENNAN COS INC     COM             571748102  6.700467e+07
# MASTERCARD INC               CL A            57636Q104  1.386277e+09
# MCKESSON CORP                COM             58155Q103  1.071160e+09
# MONDELEZ INTL INC            CL A            609207105  3.852370e+07
# MOODYS CORP                  COM             615369105  6.873494e+09
# NU HLDGS LTD                 ORD SHS CL A    G6683N103  4.359735e+08
# OCCIDENTAL PETE CORP         COM             674599105  1.224221e+10
# PARAMOUNT GLOBAL             CLASS B COM     92556H206  1.580596e+09
# PROCTER & GAMBLE CO          COM             742718109  4.780202e+07
# RH                           COM             74967X103  6.305684e+08
# SNOWFLAKE INC                CL A            833445109  8.792365e+08
# SPDR S&P 500 ETF TR          TR UNIT         78462F103  1.506774e+07
# STONECO LTD                  COM CL A        G85158106  1.009650e+08
# T-MOBILE US INC              COM             872590104  7.338800e+08
# TAIWAN SEMICONDUCTOR MFG LTD SPONSORED ADS   874039100  6.177250e+08
# UNITED PARCEL SERVICE INC    CL B            911312106  1.032610e+07
# US BANCORP DEL               COM NEW         902973304  2.909151e+08
# VANGUARD INDEX FDS           S&P 500 ETF SHS 922908363  1.510762e+07
# VERISIGN INC                 COM             92343E102  2.632840e+09
# VISA INC                     COM CL A        92826C839  1.723880e+09
# NU HLDGS LTD                 ORD SHS CL A    G6693N103           NaN
#
#                                                         amount_prior  \
# issuer                       security_type   cusip
# ACTIVISION BLIZZARD INC      COM             00507V109  6.014187e+07
# ALLY FINL INC                COM             02005N100  3.000000e+07
# AMAZON COM INC               COM             023135106  1.066600e+07
# AMERICAN EXPRESS CO          COM             025816109  1.516107e+08
# AON PLC                      SHS CL A        G0403H108  4.396000e+06
# APPLE INC                    COM             037833100  8.948023e+08
# BANK AMER CORP               COM             060505104  1.010101e+09
# BANK OF NEW YORK MELLON CORP COM             064058100  6.221088e+07
# CELANESE CORP DEL            COM             150870103  9.710183e+06
# CHARTER COMMUNICATIONS INC N CL A            16119P108  3.828941e+06
# CHEVRON CORP NEW             COM             166764100  1.653593e+08
# CITIGROUP INC                COM NEW         172967424  5.515580e+07
# COCA COLA CO                 COM             191216100  4.000000e+08
# DAVITA INC                   COM             23918K108  3.609557e+07
# FLOOR & DECOR HLDGS INC      CL A            339750101  4.780000e+06
# GENERAL MTRS CO              COM             37045V100  5.000000e+07
# GLOBE LIFE INC               COM             37959E102  6.353727e+06
# HP INC                       COM             40434L105  1.044760e+08
# JEFFERIES FINL GROUP INC     COM             47233W109  4.335580e+05
# JOHNSON & JOHNSON            COM             478160104  3.271000e+05
# KRAFT HEINZ CO               COM             500754106  3.256348e+08
# KROGER CO                    COM             501044101  5.026882e+07
# LIBERTY LATIN AMERICA LTD    COM CL A        G9001E102  2.630792e+06
#                              COM CL C        G9001E128  1.284020e+06
# LIBERTY MEDIA CORP DEL       COM SER C FRMLA 531229854  7.722451e+06
# LIBERTY MEDIA CORP DELAWARE  COM A SIRIUSXM  531229409  2.020768e+07
#                              COM C SIRIUSXM  531229607  4.320829e+07
# LOUISIANA PAC CORP           COM             546347105  5.795906e+06
# MARKEL CORP                  COM             570535104  4.676110e+05
# MARSH & MCLENNAN COS INC     COM             571748102  4.049110e+05
# MASTERCARD INC               CL A            57636Q104  3.986648e+06
# MCKESSON CORP                COM             58155Q103  3.198344e+06
# MONDELEZ INTL INC            CL A            609207105  5.780000e+05
# MOODYS CORP                  COM             615369105  2.466978e+07
# NU HLDGS LTD                 ORD SHS CL A    G6683N103           NaN
# OCCIDENTAL PETE CORP         COM             674599105  1.943516e+08
# PARAMOUNT GLOBAL             CLASS B COM     92556H206  9.121651e+07
# PROCTER & GAMBLE CO          COM             742718109  3.154000e+05
# RH                           COM             74967X103  2.360000e+06
# SNOWFLAKE INC                CL A            833445109  6.125376e+06
# SPDR S&P 500 ETF TR          TR UNIT         78462F103  3.940000e+04
# STONECO LTD                  COM CL A        G85158106  1.069545e+07
# T-MOBILE US INC              COM             872590104  5.242000e+06
# TAIWAN SEMICONDUCTOR MFG LTD SPONSORED ADS   874039100  6.006088e+07
# UNITED PARCEL SERVICE INC    CL B            911312106  5.940000e+04
# US BANCORP DEL               COM NEW         902973304  7.778821e+07
# VANGUARD INDEX FDS           S&P 500 ETF SHS 922908363  4.300000e+04
# VERISIGN INC                 COM             92343E102  1.281561e+07
# VISA INC                     COM CL A        92826C839  8.297460e+06
# NU HLDGS LTD                 ORD SHS CL A    G6693N103  1.071188e+08
#
#                                                         value_prior
# issuer                       security_type   cusip
# ACTIVISION BLIZZARD INC      COM             00507V109    4470946.0
# ALLY FINL INC                COM             02005N100     834901.0
# AMAZON COM INC               COM             023135106    1205258.0
# AMERICAN EXPRESS CO          COM             025816109   20453800.0
# AON PLC                      SHS CL A        G0403H108    1177556.0
# APPLE INC                    COM             037833100  123661679.0
# BANK AMER CORP               COM             060505104   30505039.0
# BANK OF NEW YORK MELLON CORP COM             064058100    2396364.0
# CELANESE CORP DEL            COM             150870103     877219.0
# CHARTER COMMUNICATIONS INC N CL A            16119P108    1161509.0
# CHEVRON CORP NEW             COM             166764100   23757173.0
# CITIGROUP INC                COM NEW         172967424    2298341.0
# COCA COLA CO                 COM             191216100   22407999.0
# DAVITA INC                   COM             23918K108    2987630.0
# FLOOR & DECOR HLDGS INC      CL A            339750101     335843.0
# GENERAL MTRS CO              COM             37045V100    1604500.0
# GLOBE LIFE INC               COM             37959E102     633467.0
# HP INC                       COM             40434L105    2603542.0
# JEFFERIES FINL GROUP INC     COM             47233W109      12790.0
# JOHNSON & JOHNSON            COM             478160104      53435.0
# KRAFT HEINZ CO               COM             500754106   10859921.0
# KROGER CO                    COM             501044101    2199260.0
# LIBERTY LATIN AMERICA LTD    COM CL A        G9001E102      16285.0
#                              COM CL C        G9001E128       7897.0
# LIBERTY MEDIA CORP DEL       COM SER C FRMLA 531229854     451764.0
# LIBERTY MEDIA CORP DELAWARE  COM A SIRIUSXM  531229409     769307.0
#                              COM C SIRIUSXM  531229607    1629386.0
# LOUISIANA PAC CORP           COM             546347105     296692.0
# MARKEL CORP                  COM             570535104     506993.0
# MARSH & MCLENNAN COS INC     COM             571748102      60449.0
# MASTERCARD INC               CL A            57636Q104    1133563.0
# MCKESSON CORP                COM             58155Q103    1087021.0
# MONDELEZ INTL INC            CL A            609207105      31692.0
# MOODYS CORP                  COM             615369105    5997470.0
# NU HLDGS LTD                 ORD SHS CL A    G6683N103          NaN
# OCCIDENTAL PETE CORP         COM             674599105   11942909.0
# PARAMOUNT GLOBAL             CLASS B COM     92556H206    1736763.0
# PROCTER & GAMBLE CO          COM             742718109      39819.0
# RH                           COM             74967X103     580724.0
# SNOWFLAKE INC                CL A            833445109    1041069.0
# SPDR S&P 500 ETF TR          TR UNIT         78462F103      14073.0
# STONECO LTD                  COM CL A        G85158106     101928.0
# T-MOBILE US INC              COM             872590104     703319.0
# TAIWAN SEMICONDUCTOR MFG LTD SPONSORED ADS   874039100    4117774.0
# UNITED PARCEL SERVICE INC    CL B            911312106       9595.0
# US BANCORP DEL               COM NEW         902973304    3136420.0
# VANGUARD INDEX FDS           S&P 500 ETF SHS 922908363      14117.0
# VERISIGN INC                 COM             92343E102    2226072.0
# VISA INC                     COM CL A        92826C839    1474044.0
# NU HLDGS LTD                 ORD SHS CL A    G6693N103     471323.0

# %% [markdown]
# # This part of the docs was helpful in refactoring my XML parsing code
# ## Parsing XML with Namespaces
#
# https://docs.python.org/3/library/xml.etree.elementtree.html
#
# If the XML input has namespaces, tags and attributes with prefixes in the form prefix:sometag get expanded to {uri}sometag where the prefix is replaced by the full URI. Also, if there is a default namespace, that full URI gets prepended to all of the non-prefixed tags.
#
# Here is an XML example that incorporates two namespaces, one with the prefix “fictional” and the other serving as the default namespace:
#
# <?xml version="1.0"?>
# <actors xmlns:fictional="http://characters.example.com"
#         xmlns="http://people.example.com">
#     <actor>
#         <name>John Cleese</name>
#         <fictional:character>Lancelot</fictional:character>
#         <fictional:character>Archie Leach</fictional:character>
#     </actor>
#     <actor>
#         <name>Eric Idle</name>
#         <fictional:character>Sir Robin</fictional:character>
#         <fictional:character>Gunther</fictional:character>
#         <fictional:character>Commander Clement</fictional:character>
#     </actor>
# </actors>
#
# One way to search and explore this XML example is to manually add the URI to every tag or attribute in the xpath of a find() or findall():
#
# root = fromstring(xml_text)
# for actor in
# root.findall('{http://people.example.com}actor'):
#     name = actor.find('{http://people.example.com}name')
#     print(name.text)
#     for char in actor.findall('{http://characters.example.com}character'):
#         print(' |-->', char.text)
#
# A better way to search the namespaced XML example is to create a dictionary with your own prefixes and use those in the search functions:
#
# ns = {'real_person': 'http://people.example.com',
#       'role': 'http://characters.example.com'}
#
# for actor in root.findall('real_person:actor', ns):
#     name = actor.find('real_person:name', ns)
#     print(name.text)
#     for char in actor.findall('role:character', ns):
#         print(' |-->', char.text)
